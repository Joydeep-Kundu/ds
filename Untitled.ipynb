# %%
import pandas as pd
df=pd.read_csv("./Running_down.csv")
#Datafr object accept data frame as paramerer
#df for dataframe, av for number of col average
class Datafr:
    def __init__(self,df):
        self.dataframe=df
        
    def dataframeavg(self,av,date='timestamp',status='SystemStatus',fail='System Down'):
        row,col=(self.dataframe.shape)
        di={}
        li=[]
        for i in self.dataframe.columns:
            di[i]=[]
            li.append(i)
        c=0
        for i in range(row):
            if c!=av-1:
                try:
                    if self.dataframe[status][i]!=self.dataframe[status][i+1]:
                        if c!=0:
                            n=0
                            for j in li:
                                if j==date or j==status:
                                    di[j].append(self.dataframe.loc[i-c][n])
                                else:
                                    di[j].append(self.dataframe[j][i-c:i+1].mean())
                                n+=1 
                        else:
                           
                            n=0
                            for j in li:
                                di[j].append(self.dataframe.loc[i][n])
                                n+=1
                        c=-1
                except:
                    print(c,i,row)
                    c+=1
                    if c>0:
                        n=0
                        for j in li:
                            if j==date or j==status:
                                di[j].append(self.dataframe.loc[row-c][n])
                            else:
                                di[j].append(self.dataframe[j][row-c:].mean())
                            n+=1
                    else:  
                        n=0
                        for j in li:
                            di[j].append(self.dataframe.loc[i][n])
                            n+=1
            if c==av-1:
                n=0
                for j in li:
                    if j==date or j==status:
                        di[j].append(self.dataframe.loc[i-c][n])
                    else:
                        di[j].append(self.dataframe[j][i-c:i+1].mean())
                    n+=1
                c=-1
            c+=1
        return di
dd=Datafr(df)
ss=pd.DataFrame(dd.dataframeavg(9))
ss
# Out:
#                       timestamp  MTH_MIL_IML1_SYSFAN_VIB_VI_A  \
# 0     2022-08-01 00:01:00+00:00                      0.128954
# 1     2022-08-01 00:10:00+00:00                      0.140945
# 2     2022-08-01 00:19:00+00:00                      0.136048
# 3     2022-08-01 00:28:00+00:00                      0.151403
# 4     2022-08-01 00:37:00+00:00                      0.156269
# ...                         ...                           ...
# 9117  2022-10-01 00:14:00+00:00                      0.276547
# 9118  2022-10-01 00:23:00+00:00                      0.275897
# 9119  2022-10-01 00:32:00+00:00                      0.274194
# 9120  2022-10-01 00:41:00+00:00                      0.275088
# 9121  2022-10-01 00:50:00+00:00                      0.279223
#
#       MTH_MIL_CGML_MTRS_XXX_YI_A  MTH_MIL_IML1_ITEMP_XXX_TI_A  \
# 0                            1.0                   120.909467
# 1                            1.0                   120.165256
# 2                            1.0                   117.812989
# 3                            1.0                   117.392633
# 4                            1.0                   115.480956
# ...                          ...                          ...
# 9117                         1.0                    76.585488
# 9118                         1.0                    76.497101
# 9119                         1.0                    76.499457
# 9120                         1.0                    76.281690
# 9121                         1.0                    76.051084
#
#       MTH_MIL_IML1_MMTR_AMPS_II_A  MTH_MIL_IML1_MMTR_IBTEMP_TI_A  \
# 0                        9.418819                     111.821956
# 1                        9.434959                     111.841144
# 2                        9.419910                     111.461644
# 3                        9.422309                     110.823922
# 4                        9.426670                     109.800600
# ...                           ...                            ...
# 9117                     9.412276                      77.322647
# 9118                     9.403115                      77.176957
# 9119                     9.402243                      77.046967
# 9120                     9.421873                      77.067904
# 9121                     9.424272                      77.151657
#
#       MTH_MIL_IML1_MMTR_OBTEMP_TI_A  MTH_MIL_IML1_MMTR_VIB_VI_A  \
# 0                        131.499922                    0.043000
# 1                        131.092544                    0.042889
# 2                        131.566256                    0.043364
# 3                        131.447600                    0.042409
# 4                        130.337878                    0.042509
# ...                             ...                         ...
# 9117                      92.082016                    0.048463
# 9118                      91.738288                    0.048478
# 9119                      91.552463                    0.049371
# 9120                      91.507970                    0.048856
# 9121                      91.348321                    0.048701
#
#       MTH_MIL_IML1_MTRS_XXX_YI_A  MTH_MIL_IML1_SYSFAN_AMPS_II_A  ...  \
# 0                            1.0                            NaN  ...
# 1                            1.0                            NaN  ...
# 2                            1.0                            NaN  ...
# 3                            1.0                            NaN  ...
# 4                            1.0                            NaN  ...
# ...                          ...                            ...  ...
# 9117                         1.0                            0.0  ...
# 9118                         1.0                            0.0  ...
# 9119                         1.0                            0.0  ...
# 9120                         1.0                            0.0  ...
# 9121                         1.0                            0.0  ...
#
#       MTH_MIL_IML1_SYSFAN_PFL_PCT_A  MTH_MIL_IML1_SYSFAN_POUT_PCT_A  \
# 0                         65.027537                       37.239069
# 1                         65.027541                       37.159550
# 2                         65.074466                       36.991706
# 3                         65.078490                       36.828143
# 4                         65.044967                       36.703978
# ...                             ...                             ...
# 9117                      64.989997                       35.726633
# 9118                      64.939051                       35.920969
# 9119                      64.964524                       35.942673
# 9120                      64.977930                       36.003534
# 9121                      65.042291                       35.855584
#
#       MTH_MIL_IML1_VENT_XXX_TI_A  MTH_MIL_IML2_MTRS_XXX_YI_A  \
# 0                     119.842867                         1.0
# 1                     118.355389                         1.0
# 2                     117.098267                         1.0
# 3                     115.852478                         1.0
# 4                     114.932956                         1.0
# ...                          ...                         ...
# 9117                   79.737466                         1.0
# 9118                   79.669419                         1.0
# 9119                   79.584796                         1.0
# 9120                   79.551647                         1.0
# 9121                   79.440850                         1.0
#
#       MTH_MIL_IML3_MTRS_XXX_YI_A  MTH_MIL_STCO_SSILO1_LEVEL_AI_A  \
# 0                            1.0                      300.150378
# 1                            1.0                      300.238711
# 2                            1.0                      303.053033
# 3                            1.0                      302.748767
# 4                            1.0                      299.107589
# ...                          ...                             ...
# 9117                         1.0                      204.114822
# 9118                         1.0                      205.745678
# 9119                         1.0                      208.911678
# 9120                         1.0                      212.801511
# 9121                         1.0                      219.417356
#
#       MTH_MIL_STCO_SSILO2_LEVEL_AI_A  MTH_WE1_STCO_SILO1_LTON_AI_A  \
# 0                         253.096044                    376.013600
# 1                         249.571811                    374.797467
# 2                         247.101800                    376.288389
# 3                         242.910978                    374.911756
# 4                         240.785300                    374.509567
# ...                              ...                           ...
# 9117                      158.718333                    376.766500
# 9118                      153.940278                    385.312578
# 9119                      148.682944                    390.068933
# 9120                      145.339433                    390.436211
# 9121                      143.411689                    390.396956
#
#       MTH_WE1_STCO_SILO2_LTON_AI_A  SystemStatus
# 0                       375.072267       Running
# 1                       373.640656       Running
# 2                       376.489056       Running
# 3                       374.444133       Running
# 4                       376.127889       Running
# ...                            ...           ...
# 9117                    374.274033       Running
# 9118                    380.737667       Running
# 9119                    387.010278       Running
# 9120                    392.229878       Running
# 9121                    392.474167       Running
#
# [9122 rows x 22 columns]

# %%
df
# Out:
#                        timestamp  MTH_MIL_IML1_SYSFAN_VIB_VI_A  \
# 0      2022-08-01 00:01:00+00:00                      0.120127
# 1      2022-08-01 00:02:00+00:00                      0.118086
# 2      2022-08-01 00:03:00+00:00                      0.129215
# 3      2022-08-01 00:04:00+00:00                      0.118832
# 4      2022-08-01 00:05:00+00:00                      0.133710
# ...                          ...                           ...
# 81945  2022-10-01 00:54:00+00:00                      0.283991
# 81946  2022-10-01 00:55:00+00:00                      0.274569
# 81947  2022-10-01 00:56:00+00:00                      0.283598
# 81948  2022-10-01 00:57:00+00:00                      0.270898
# 81949  2022-10-01 00:58:00+00:00                      0.281773
#
#        MTH_MIL_CGML_MTRS_XXX_YI_A  MTH_MIL_IML1_ITEMP_XXX_TI_A  \
# 0                             1.0                    120.31250
# 1                             1.0                    120.45670
# 2                             1.0                    122.97220
# 3                             1.0                    121.94950
# 4                             1.0                    121.42450
# ...                           ...                          ...
# 81945                         1.0                     76.04747
# 81946                         1.0                     76.16247
# 81947                         1.0                     76.20459
# 81948                         1.0                     76.04757
# 81949                         1.0                     75.85078
#
#        MTH_MIL_IML1_MMTR_AMPS_II_A  MTH_MIL_IML1_MMTR_IBTEMP_TI_A  \
# 0                         9.386322                      111.71200
# 1                         9.431469                      111.86910
# 2                         9.394173                      111.78270
# 3                         9.362766                      111.67280
# 4                         9.466801                      111.87690
# ...                            ...                            ...
# 81945                     9.470728                       77.27467
# 81946                     9.470728                       77.24326
# 81947                     9.494282                       77.08623
# 81948                     9.504097                       77.21185
# 81949                     9.384359                       77.08623
#
#        MTH_MIL_IML1_MMTR_OBTEMP_TI_A  MTH_MIL_IML1_MMTR_VIB_VI_A  \
# 0                          131.60810                    0.040609
# 1                          131.57670                    0.043534
# 2                          131.54530                    0.045811
# 3                          131.49030                    0.041669
# 4                          131.49820                    0.039706
# ...                              ...                         ...
# 81945                       91.32127                    0.048775
# 81946                       91.32913                    0.047538
# 81947                       91.33698                    0.048716
# 81948                       91.32127                    0.048598
# 81949                       91.32913                    0.050601
#
#        MTH_MIL_IML1_MTRS_XXX_YI_A  MTH_MIL_IML1_SYSFAN_AMPS_II_A  ...  \
# 0                             1.0                            NaN  ...
# 1                             1.0                            NaN  ...
# 2                             1.0                            NaN  ...
# 3                             1.0                            NaN  ...
# 4                             1.0                            NaN  ...
# ...                           ...                            ...  ...
# 81945                         1.0                            0.0  ...
# 81946                         1.0                            0.0  ...
# 81947                         1.0                            0.0  ...
# 81948                         1.0                            0.0  ...
# 81949                         1.0                            0.0  ...
#
#        MTH_MIL_IML1_SYSFAN_PFL_PCT_A  MTH_MIL_IML1_SYSFAN_POUT_PCT_A  \
# 0                           65.05167                        37.12894
# 1                           64.93100                        37.33164
# 2                           64.91893                        37.36421
# 3                           65.01547                        37.27627
# 4                           65.06374                        37.22665
# ...                              ...                             ...
# 81945                       65.00341                        35.88640
# 81946                       65.08788                        35.78426
# 81947                       65.00341                        35.85372
# 81948                       64.79826                        36.06885
# 81949                       64.96721                        35.91431
#
#        MTH_MIL_IML1_VENT_XXX_TI_A  MTH_MIL_IML2_MTRS_XXX_YI_A  \
# 0                       120.15260                         1.0
# 1                       120.24680                         1.0
# 2                       120.15260                         1.0
# 3                       120.10540                         1.0
# 4                       119.66580                         1.0
# ...                           ...                         ...
# 81945                    79.61446                         1.0
# 81946                    79.57520                         1.0
# 81947                    79.27684                         1.0
# 81948                    79.11980                         1.0
# 81949                    79.61446                         1.0
#
#        MTH_MIL_IML3_MTRS_XXX_YI_A  MTH_MIL_STCO_SSILO1_LEVEL_AI_A  \
# 0                             1.0                        298.2709
# 1                             1.0                        297.7483
# 2                             1.0                        298.5211
# 3                             1.0                        299.1616
# 4                             1.0                        300.4424
# ...                           ...                             ...
# 81945                         1.0                        219.5458
# 81946                         1.0                        220.2230
# 81947                         1.0                        220.8339
# 81948                         1.0                        221.3418
# 81949                         1.0                        222.3871
#
#        MTH_MIL_STCO_SSILO2_LEVEL_AI_A  MTH_WE1_STCO_SILO1_LTON_AI_A  \
# 0                            254.8561                      377.6476
# 1                            254.4881                      377.6869
# 2                            254.0832                      376.2971
# 3                            253.6489                      374.8210
# 4                            253.1926                      374.7975
# ...                               ...                           ...
# 81945                        143.1761                      390.1553
# 81946                        142.9774                      390.5164
# 81947                        143.0878                      390.5557
# 81948                        143.2424                      390.2888
# 81949                        143.4632                      390.1789
#
#        MTH_WE1_STCO_SILO2_LTON_AI_A  SystemStatus
# 0                          375.1272       Running
# 1                          373.8317       Running
# 2                          373.0387       Running
# 3                          371.9002       Running
# 4                          372.0179       Running
# ...                             ...           ...
# 81945                      393.5708       Running
# 81946                      392.8013       Running
# 81947                      392.4480       Running
# 81948                      391.9690       Running
# 81949                      392.1261       Running
#
# [81950 rows x 22 columns]
